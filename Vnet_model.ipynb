# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshithasree/Brain_tumor_segmenttion_and_survival_prediction_using_deep_learning/blob/main/Vnet_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
drive.mount('/content/drive',force_remount=True)
os.chdir('/content/drive/My Drive/')
# Out:
# Mounted at /content/drive

# %%
# !pip install SimpleITK
# Out:
# Collecting SimpleITK
#   Downloading SimpleITK-2.1.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (48.4 MB)
#      |████████████████████████████████| 48.4 MB 1.8 MB/s
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.1.1

# %%
import SimpleITK as sitk 
from tqdm import tqdm
import numpy as np

from keras.utils.np_utils import to_categorical,normalize
from keras.models import Model
from keras.layers import MaxPooling2D,add,Input,Dropout,Conv2D,Dense,BatchNormalization,Concatenate,Input,Dropout,Maximum,Activation,Dense,Flatten,UpSampling2D,Conv2DTranspose,Add,Multiply,Lambda,PReLU,concatenate
from tensorflow.keras.optimizers import SGD,Adam,RMSprop,Nadam
import keras.callbacks as callbacks
import keras.initializers as initializers
from keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler
from keras import regularizers
from keras import backend as K
import keras as ke
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib as sk
import skimage.io as io
import skimage.transform as trans

# %% [markdown]
# #Loading data

# %%
path = './HGG1/'

# %%
def load_data(path):
  my_dir = sorted(os.listdir(path))
  data = []
  gt = []
  count=0
  
  for p in tqdm(my_dir):
    count+=1
    data_list = sorted(os.listdir(path+p))
    img_itk = sitk.ReadImage(path + p + '/'+ data_list[0])
    flair = sitk.GetArrayFromImage(img_itk)
    img_itk = sitk.ReadImage(path + p + '/'+ data_list[1])
    seg =  sitk.GetArrayFromImage(img_itk)
    img_itk = sitk.ReadImage(path + p + '/'+ data_list[2])    
    t1 =  sitk.GetArrayFromImage(img_itk)
    img_itk = sitk.ReadImage(path + p + '/'+ data_list[3])
    t1ce =  sitk.GetArrayFromImage(img_itk)
    img_itk = sitk.ReadImage(path + p + '/'+ data_list[4])
    t2 =  sitk.GetArrayFromImage(img_itk)
    data.append([flair,t1,t1ce,t2])
    gt.append(seg)
    if(count==10):
      break
  data = np.asarray(data,dtype=np.float32)
  gt = np.asarray(gt,dtype=np.uint8)
  return data,gt

# %%
#HGG
data,gt = load_data(path)
# Out:
#  18%|█▊        | 9/50 [00:05<00:22,  1.79it/s]

# %%
data.shape,gt.shape,data.dtype,gt.dtype
# Out:
# ((10, 4, 155, 240, 240), (10, 155, 240, 240), dtype('float32'), dtype('uint8'))

# %%
plt.imshow(data[0,2,65,:,:])
plt.show()
plt.imshow(gt[0,65,:,:])
plt.show()

# %%
data = np.transpose(data,(0,2,3,4,1))

# %%
data.shape,gt.shape,data.dtype,gt.dtype
# Out:
# ((10, 155, 240, 240, 4), (10, 155, 240, 240), dtype('float32'), dtype('uint8'))

# %%
import matplotlib.pyplot as plt
plt.imshow(data[0,70,:,:,2])
plt.show()
plt.imshow(gt[0,70,:,:])
plt.show()

# %% [markdown]
# # Pre-Processing

# %%
data.shape,gt.shape
# Out:
# ((10, 155, 240, 240, 4), (10, 155, 240, 240))

# %%
data = data[:,30:120,30:222,30:222,:].reshape([-1,192,192,4])   #taking 30-120 slices
gt = gt[:,30:120,30:222,30:222].reshape([-1,192,192,1])

# %%
data.shape,gt.shape
# Out:
# ((900, 192, 192, 4), (900, 192, 192, 1))

# %%
gt[np.where(gt==4)]=3   #converting ground truth value of 4 to 3 => one hot encoding

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data, gt, test_size=0.2, random_state=42)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.25,random_state=42)

# %%
Y_train = to_categorical(Y_train)
Y_val = to_categorical(Y_val)
X_train = (X_train-np.mean(X_train))/np.max(X_train)
X_test = (X_test-np.mean(X_test))/np.max(X_test)
X_val = (X_val-np.mean(X_val))/np.max(X_val)

# %%
X_train.shape,Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape
# Out:
# ((540, 192, 192, 4),
#  (540, 192, 192, 4),
#  (180, 192, 192, 4),
#  (180, 192, 192, 4),
#  (180, 192, 192, 4),
#  (180, 192, 192, 1))

# %%
plt.imshow(X_train[0,:,:,1])
plt.show()
plt.imshow(Y_train[0,:,:,1])
plt.show()

# %%
X_train.shape,Y_train.shape,X_val.shape,Y_val.shape
# Out:
# ((540, 192, 192, 4),
#  (540, 192, 192, 4),
#  (180, 192, 192, 4),
#  (180, 192, 192, 4))

# %% [markdown]
# ## VNet model

# %%
def dice_coef(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    return (2. * intersection) / (K.sum(K.square(y_true),axis=-1) + K.sum(K.square(y_pred),axis=-1) + epsilon)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
def resBlock(conv,stage,keep_prob,stage_num=5):
    inputs=conv
    
    for _ in range(3 if stage>3 else stage):
        conv=PReLU()(BatchNormalization()(Conv2D(16*(2**(stage-1)), 5, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv)))
    conv_add=PReLU()(add([inputs,conv]))
    conv_drop=Dropout(keep_prob)(conv_add)
    
    if stage<stage_num:
        conv_downsample=PReLU()(BatchNormalization()(Conv2D(16*(2**stage), 2, strides=(2, 2),activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv_drop)))
        return conv_downsample,conv_add
    else:
        return conv_add,conv_add
         
def up_resBlock(forward_conv,input_conv,stage):
    conv=concatenate([forward_conv,input_conv],axis = -1)
  
    for _ in range(3 if stage>3 else stage):
        conv=PReLU()(BatchNormalization()(Conv2D(16*(2**(stage-1)), 5, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv)))
    conv_add=PReLU()(add([input_conv,conv]))
    if stage>1:
        conv_upsample=PReLU()(BatchNormalization()(Conv2DTranspose(16*(2**(stage-2)),2,strides=(2, 2),padding='valid',activation = None,kernel_initializer = 'he_normal')(conv_add)))
        return conv_upsample
    else:
        return conv_add

def vnet(pretrained_weights = None,input_size = (192,192,4),num_class=1,is_training=True,stage_num=5,thresh=0.5):
    keep_prob = 0.1
    features=[]
    input_model = Input(input_size)
    x=PReLU()(BatchNormalization()(Conv2D(16, 5, activation = None, padding = 'same', kernel_initializer = 'he_normal')(input_model)))
    
    for s in range(1,stage_num+1):
        x,feature=resBlock(x,s,keep_prob,stage_num)
        features.append(feature)
        
    conv_up=PReLU()(BatchNormalization()(Conv2DTranspose(16*(2**(s-2)),2,strides=(2, 2),padding='valid',activation = None,kernel_initializer = 'he_normal')(x)))
    
    for d in range(stage_num-1,0,-1):
        conv_up=up_resBlock(features[d-1],conv_up,d)
    if num_class>1:
        conv_out=Conv2D(num_class, 1, activation = 'softmax', padding = 'same', kernel_initializer = 'he_normal')(conv_up)
    else:
        conv_out=Conv2D(num_class, 1, activation = 'sigmoid', padding = 'same', kernel_initializer = 'he_normal')(conv_up)
    
    
    
    
    model=Model(inputs=input_model,outputs=conv_out)    

    model.compile(optimizer = Nadam(lr = 2e-4),loss=dice_coef_loss,metrics=[dice_coef,'accuracy'])
    
    if(pretrained_weights):
    	model.load_weights(pretrained_weights)
    return model
model=vnet(input_size = (192,192,4),num_class=4,stage_num=5)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 192, 4  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 192, 192, 16  1616        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 192, 192, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  p_re_lu (PReLU)                (None, 192, 192, 16  589824      ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 192, 192, 16  6416        ['p_re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 192, 192, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  p_re_lu_1 (PReLU)              (None, 192, 192, 16  589824      ['batch_normalization_1[0][0]']
#                                 )
#
#  add (Add)                      (None, 192, 192, 16  0           ['p_re_lu[0][0]',
#                                 )                                 'p_re_lu_1[0][0]']
#
#  p_re_lu_2 (PReLU)              (None, 192, 192, 16  589824      ['add[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 192, 192, 16  0           ['p_re_lu_2[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 96, 96, 32)   2080        ['dropout[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 96, 96, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  p_re_lu_3 (PReLU)              (None, 96, 96, 32)   294912      ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 96, 96, 32)   25632       ['p_re_lu_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 96, 96, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  p_re_lu_4 (PReLU)              (None, 96, 96, 32)   294912      ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 96, 96, 32)   25632       ['p_re_lu_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96, 96, 32)  128         ['conv2d_4[0][0]']
#  rmalization)
#
#  p_re_lu_5 (PReLU)              (None, 96, 96, 32)   294912      ['batch_normalization_4[0][0]']
#
#  add_1 (Add)                    (None, 96, 96, 32)   0           ['p_re_lu_3[0][0]',
#                                                                   'p_re_lu_5[0][0]']
#
#  p_re_lu_6 (PReLU)              (None, 96, 96, 32)   294912      ['add_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 96, 96, 32)   0           ['p_re_lu_6[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 48, 48, 64)   8256        ['dropout_1[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 48, 48, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  p_re_lu_7 (PReLU)              (None, 48, 48, 64)   147456      ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 48, 48, 64)   102464      ['p_re_lu_7[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 48, 48, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  p_re_lu_8 (PReLU)              (None, 48, 48, 64)   147456      ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 48, 48, 64)   102464      ['p_re_lu_8[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 48, 48, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  p_re_lu_9 (PReLU)              (None, 48, 48, 64)   147456      ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 48, 48, 64)   102464      ['p_re_lu_9[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 48, 48, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  p_re_lu_10 (PReLU)             (None, 48, 48, 64)   147456      ['batch_normalization_8[0][0]']
#
#  add_2 (Add)                    (None, 48, 48, 64)   0           ['p_re_lu_7[0][0]',
#                                                                   'p_re_lu_10[0][0]']
#
#  p_re_lu_11 (PReLU)             (None, 48, 48, 64)   147456      ['add_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 48, 48, 64)   0           ['p_re_lu_11[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 24, 24, 128)  32896       ['dropout_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 24, 24, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  p_re_lu_12 (PReLU)             (None, 24, 24, 128)  73728       ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 24, 24, 128)  409728      ['p_re_lu_12[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 24, 24, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  p_re_lu_13 (PReLU)             (None, 24, 24, 128)  73728       ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 24, 24, 128)  409728      ['p_re_lu_13[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 24, 24, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  p_re_lu_14 (PReLU)             (None, 24, 24, 128)  73728       ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 24, 24, 128)  409728      ['p_re_lu_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 24, 24, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  p_re_lu_15 (PReLU)             (None, 24, 24, 128)  73728       ['batch_normalization_12[0][0]']
#
#  add_3 (Add)                    (None, 24, 24, 128)  0           ['p_re_lu_12[0][0]',
#                                                                   'p_re_lu_15[0][0]']
#
#  p_re_lu_16 (PReLU)             (None, 24, 24, 128)  73728       ['add_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 24, 24, 128)  0           ['p_re_lu_16[0][0]']
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/nadam.py:73: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Nadam, self).__init__(name, **kwargs)
#  conv2d_13 (Conv2D)             (None, 12, 12, 256)  131328      ['dropout_3[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  p_re_lu_17 (PReLU)             (None, 12, 12, 256)  36864       ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 256)  1638656     ['p_re_lu_17[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  p_re_lu_18 (PReLU)             (None, 12, 12, 256)  36864       ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 12, 12, 256)  1638656     ['p_re_lu_18[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  p_re_lu_19 (PReLU)             (None, 12, 12, 256)  36864       ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 12, 12, 256)  1638656     ['p_re_lu_19[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  p_re_lu_20 (PReLU)             (None, 12, 12, 256)  36864       ['batch_normalization_16[0][0]']
#
#  add_4 (Add)                    (None, 12, 12, 256)  0           ['p_re_lu_17[0][0]',
#                                                                   'p_re_lu_20[0][0]']
#
#  p_re_lu_21 (PReLU)             (None, 12, 12, 256)  36864       ['add_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 24, 24, 128)  131200     ['p_re_lu_21[0][0]']
#  ose)
#
#  batch_normalization_17 (BatchN  (None, 24, 24, 128)  512        ['conv2d_transpose[0][0]']
#  ormalization)
#
#  p_re_lu_22 (PReLU)             (None, 24, 24, 128)  73728       ['batch_normalization_17[0][0]']
#
#  concatenate (Concatenate)      (None, 24, 24, 256)  0           ['p_re_lu_16[0][0]',
#                                                                   'p_re_lu_22[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 24, 24, 128)  819328      ['concatenate[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 24, 24, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  p_re_lu_23 (PReLU)             (None, 24, 24, 128)  73728       ['batch_normalization_18[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 24, 24, 128)  409728      ['p_re_lu_23[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 24, 24, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  p_re_lu_24 (PReLU)             (None, 24, 24, 128)  73728       ['batch_normalization_19[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 24, 24, 128)  409728      ['p_re_lu_24[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 24, 24, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  p_re_lu_25 (PReLU)             (None, 24, 24, 128)  73728       ['batch_normalization_20[0][0]']
#
#  add_5 (Add)                    (None, 24, 24, 128)  0           ['p_re_lu_22[0][0]',
#                                                                   'p_re_lu_25[0][0]']
#
#  p_re_lu_26 (PReLU)             (None, 24, 24, 128)  73728       ['add_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 48, 48, 64)  32832       ['p_re_lu_26[0][0]']
#  spose)
#
#  batch_normalization_21 (BatchN  (None, 48, 48, 64)  256         ['conv2d_transpose_1[0][0]']
#  ormalization)
#
#  p_re_lu_27 (PReLU)             (None, 48, 48, 64)   147456      ['batch_normalization_21[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 48, 48, 128)  0           ['p_re_lu_11[0][0]',
#                                                                   'p_re_lu_27[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 48, 48, 64)   204864      ['concatenate_1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 48, 48, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  p_re_lu_28 (PReLU)             (None, 48, 48, 64)   147456      ['batch_normalization_22[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 48, 48, 64)   102464      ['p_re_lu_28[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 48, 48, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  p_re_lu_29 (PReLU)             (None, 48, 48, 64)   147456      ['batch_normalization_23[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 48, 48, 64)   102464      ['p_re_lu_29[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 48, 48, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  p_re_lu_30 (PReLU)             (None, 48, 48, 64)   147456      ['batch_normalization_24[0][0]']
#
#  add_6 (Add)                    (None, 48, 48, 64)   0           ['p_re_lu_27[0][0]',
#                                                                   'p_re_lu_30[0][0]']
#
#  p_re_lu_31 (PReLU)             (None, 48, 48, 64)   147456      ['add_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 96, 96, 32)  8224        ['p_re_lu_31[0][0]']
#  spose)
#
#  batch_normalization_25 (BatchN  (None, 96, 96, 32)  128         ['conv2d_transpose_2[0][0]']
#  ormalization)
#
#  p_re_lu_32 (PReLU)             (None, 96, 96, 32)   294912      ['batch_normalization_25[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 96, 96, 64)   0           ['p_re_lu_6[0][0]',
#                                                                   'p_re_lu_32[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 96, 96, 32)   51232       ['concatenate_2[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 96, 96, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  p_re_lu_33 (PReLU)             (None, 96, 96, 32)   294912      ['batch_normalization_26[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 96, 96, 32)   25632       ['p_re_lu_33[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 96, 96, 32)  128         ['conv2d_24[0][0]']
#  ormalization)
#
#  p_re_lu_34 (PReLU)             (None, 96, 96, 32)   294912      ['batch_normalization_27[0][0]']
#
#  add_7 (Add)                    (None, 96, 96, 32)   0           ['p_re_lu_32[0][0]',
#                                                                   'p_re_lu_34[0][0]']
#
#  p_re_lu_35 (PReLU)             (None, 96, 96, 32)   294912      ['add_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 192, 192, 16  2064       ['p_re_lu_35[0][0]']
#  spose)                         )
#
#  batch_normalization_28 (BatchN  (None, 192, 192, 16  64         ['conv2d_transpose_3[0][0]']
#  ormalization)                  )
#
#  p_re_lu_36 (PReLU)             (None, 192, 192, 16  589824      ['batch_normalization_28[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 192, 192, 32  0           ['p_re_lu_2[0][0]',
#                                 )                                 'p_re_lu_36[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 192, 192, 16  12816       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 192, 192, 16  64         ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  p_re_lu_37 (PReLU)             (None, 192, 192, 16  589824      ['batch_normalization_29[0][0]']
#                                 )
#
#  add_8 (Add)                    (None, 192, 192, 16  0           ['p_re_lu_36[0][0]',
#                                 )                                 'p_re_lu_37[0][0]']
#
#  p_re_lu_38 (PReLU)             (None, 192, 192, 16  589824      ['add_8[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 192, 192, 4)  68          ['p_re_lu_38[0][0]']
#
# ==================================================================================================
# Total params: 17,304,708
# Trainable params: 17,299,076
# Non-trainable params: 5,632
# __________________________________________________________________________________________________

# %%
checkpointer = callbacks.ModelCheckpoint(filepath = 'vnet-weights.hdf5',save_best_only=True)
training_log = callbacks.TensorBoard(log_dir='./Model_logs')

# %%
history = model.fit(X_train,Y_train,validation_data=(X_val,Y_val),batch_size=8,epochs=30,callbacks=[training_log,checkpointer],shuffle=True)
# Out:
# Epoch 1/30
# 68/68 [==============================] - 46s 305ms/step - loss: 0.3832 - dice_coef: 0.6168 - accuracy: 0.6408 - val_loss: 0.5841 - val_dice_coef: 0.4159 - val_accuracy: 0.5961
# Epoch 2/30
# 68/68 [==============================] - 15s 225ms/step - loss: 0.1226 - dice_coef: 0.8774 - accuracy: 0.9263 - val_loss: 0.2576 - val_dice_coef: 0.7424 - val_accuracy: 0.9583
# Epoch 3/30
# 68/68 [==============================] - 15s 227ms/step - loss: 0.0595 - dice_coef: 0.9405 - accuracy: 0.9676 - val_loss: 0.1524 - val_dice_coef: 0.8476 - val_accuracy: 0.9573
# Epoch 4/30
# 68/68 [==============================] - 16s 228ms/step - loss: 0.0446 - dice_coef: 0.9554 - accuracy: 0.9724 - val_loss: 0.0944 - val_dice_coef: 0.9056 - val_accuracy: 0.9607
# Epoch 5/30
# 68/68 [==============================] - 16s 231ms/step - loss: 0.0370 - dice_coef: 0.9630 - accuracy: 0.9747 - val_loss: 0.0669 - val_dice_coef: 0.9331 - val_accuracy: 0.9617
# Epoch 6/30
# 68/68 [==============================] - 16s 233ms/step - loss: 0.0316 - dice_coef: 0.9684 - accuracy: 0.9767 - val_loss: 0.0401 - val_dice_coef: 0.9599 - val_accuracy: 0.9749
# Epoch 7/30
# 68/68 [==============================] - 16s 240ms/step - loss: 0.0266 - dice_coef: 0.9734 - accuracy: 0.9796 - val_loss: 0.0296 - val_dice_coef: 0.9704 - val_accuracy: 0.9792
# Epoch 8/30
# 68/68 [==============================] - 14s 202ms/step - loss: 0.0249 - dice_coef: 0.9751 - accuracy: 0.9798 - val_loss: 0.0384 - val_dice_coef: 0.9616 - val_accuracy: 0.9677
# Epoch 9/30
# 68/68 [==============================] - 15s 221ms/step - loss: 0.0235 - dice_coef: 0.9765 - accuracy: 0.9801 - val_loss: 0.0334 - val_dice_coef: 0.9666 - val_accuracy: 0.9703
# Epoch 10/30
# 68/68 [==============================] - 14s 202ms/step - loss: 0.0194 - dice_coef: 0.9806 - accuracy: 0.9836 - val_loss: 0.0319 - val_dice_coef: 0.9681 - val_accuracy: 0.9716
# Epoch 11/30
# 68/68 [==============================] - 16s 233ms/step - loss: 0.0196 - dice_coef: 0.9804 - accuracy: 0.9826 - val_loss: 0.0210 - val_dice_coef: 0.9790 - val_accuracy: 0.9813
# Epoch 12/30
# 68/68 [==============================] - 16s 236ms/step - loss: 0.0170 - dice_coef: 0.9830 - accuracy: 0.9849 - val_loss: 0.0169 - val_dice_coef: 0.9831 - val_accuracy: 0.9850
# Epoch 13/30
# 68/68 [==============================] - 14s 201ms/step - loss: 0.0154 - dice_coef: 0.9846 - accuracy: 0.9862 - val_loss: 0.0179 - val_dice_coef: 0.9821 - val_accuracy: 0.9839
# Epoch 14/30
# 68/68 [==============================] - 15s 221ms/step - loss: 0.0147 - dice_coef: 0.9853 - accuracy: 0.9865 - val_loss: 0.0196 - val_dice_coef: 0.9804 - val_accuracy: 0.9820
# Epoch 15/30
# 68/68 [==============================] - 16s 237ms/step - loss: 0.0137 - dice_coef: 0.9863 - accuracy: 0.9875 - val_loss: 0.0157 - val_dice_coef: 0.9843 - val_accuracy: 0.9854
# Epoch 16/30
# 68/68 [==============================] - 16s 232ms/step - loss: 0.0133 - dice_coef: 0.9867 - accuracy: 0.9876 - val_loss: 0.0140 - val_dice_coef: 0.9860 - val_accuracy: 0.9866
# Epoch 17/30
# 68/68 [==============================] - 15s 220ms/step - loss: 0.0131 - dice_coef: 0.9869 - accuracy: 0.9876 - val_loss: 0.0147 - val_dice_coef: 0.9853 - val_accuracy: 0.9856
# Epoch 18/30
# 68/68 [==============================] - 16s 233ms/step - loss: 0.0129 - dice_coef: 0.9871 - accuracy: 0.9877 - val_loss: 0.0135 - val_dice_coef: 0.9865 - val_accuracy: 0.9868
# Epoch 19/30
# 68/68 [==============================] - 17s 254ms/step - loss: 0.0115 - dice_coef: 0.9885 - accuracy: 0.9890 - val_loss: 0.0128 - val_dice_coef: 0.9872 - val_accuracy: 0.9875
# Epoch 20/30
# 68/68 [==============================] - 15s 221ms/step - loss: 0.0109 - dice_coef: 0.9891 - accuracy: 0.9895 - val_loss: 0.0136 - val_dice_coef: 0.9864 - val_accuracy: 0.9867
# Epoch 21/30
# 68/68 [==============================] - 14s 201ms/step - loss: 0.0150 - dice_coef: 0.9850 - accuracy: 0.9851 - val_loss: 0.6470 - val_dice_coef: 0.3530 - val_accuracy: 0.3515
# Epoch 22/30
# 68/68 [==============================] - 14s 201ms/step - loss: 0.0151 - dice_coef: 0.9849 - accuracy: 0.9847 - val_loss: 0.0322 - val_dice_coef: 0.9678 - val_accuracy: 0.9675
# Epoch 23/30
# 68/68 [==============================] - 16s 236ms/step - loss: 0.0126 - dice_coef: 0.9874 - accuracy: 0.9872 - val_loss: 0.0127 - val_dice_coef: 0.9873 - val_accuracy: 0.9873
# Epoch 24/30
# 68/68 [==============================] - 16s 233ms/step - loss: 0.0119 - dice_coef: 0.9881 - accuracy: 0.9879 - val_loss: 0.0119 - val_dice_coef: 0.9881 - val_accuracy: 0.9881
# Epoch 25/30
# 68/68 [==============================] - 17s 246ms/step - loss: 0.0108 - dice_coef: 0.9892 - accuracy: 0.9891 - val_loss: 0.0117 - val_dice_coef: 0.9883 - val_accuracy: 0.9881
# Epoch 26/30
# 68/68 [==============================] - 16s 238ms/step - loss: 0.0101 - dice_coef: 0.9899 - accuracy: 0.9898 - val_loss: 0.0101 - val_dice_coef: 0.9899 - val_accuracy: 0.9898
# Epoch 27/30
# 68/68 [==============================] - 14s 201ms/step - loss: 0.0095 - dice_coef: 0.9905 - accuracy: 0.9903 - val_loss: 0.0104 - val_dice_coef: 0.9896 - val_accuracy: 0.9894
# Epoch 28/30
# 68/68 [==============================] - 16s 234ms/step - loss: 0.0089 - dice_coef: 0.9911 - accuracy: 0.9909 - val_loss: 0.0100 - val_dice_coef: 0.9900 - val_accuracy: 0.9897
# Epoch 29/30
# 68/68 [==============================] - 16s 234ms/step - loss: 0.0089 - dice_coef: 0.9911 - accuracy: 0.9909 - val_loss: 0.0090 - val_dice_coef: 0.9910 - val_accuracy: 0.9907
# Epoch 30/30
# 68/68 [==============================] - 14s 201ms/step - loss: 0.0086 - dice_coef: 0.9914 - accuracy: 0.9911 - val_loss: 0.0115 - val_dice_coef: 0.9885 - val_accuracy: 0.9881

# %%
a = history.history

list_traindice = a['dice_coef']
list_testdice = a['val_dice_coef']

list_trainloss = a['loss']
list_testloss = a['val_loss']

plt.figure(1)
plt.plot(list_testloss, 'b-')
plt.plot(list_trainloss,'r-')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('loss graph', fontsize = 15)
plt.figure(2)
plt.plot(list_traindice, 'r-')
plt.plot(list_testdice, 'b-')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.title('accuracy graph', fontsize = 15)
plt.show()

# %%
Y_pre = np.argmax(model.predict(X_test),axis=-1)

# %%
np.unique(Y_pre)
# Out:
# array([0, 1, 2, 3])

# %%
Y_pre.shape
# Out:
# (180, 192, 192)

# %%
Y_pre=Y_pre.reshape(-1,192,192,1)

# %%
Y_test.shape,X_test.shape
# Out:
# ((180, 192, 192, 1), (180, 192, 192, 4))

# %%
for i in range(5):
  print('X_test '+ str(i))
  plt.imshow(X_test[i,:,:,2])
  plt.show()

  print('Predicted '+ str(i))
  plt.imshow(Y_pre[i,:,:,0])
  plt.show()

  print('Actual '+ str(i))
  plt.imshow(Y_test[i,:,:,0])
  plt.show()
# Out:
# X_test 0
# Predicted 0
# Actual 0
# X_test 1
# Predicted 1
# Actual 1
# X_test 2
# Predicted 2
# Actual 2
# X_test 3
# Predicted 3
# Actual 3
# X_test 4
# Predicted 4
# Actual 4

# %%
Y_test_encod = to_categorical(Y_test)

# %%
train_result = model.evaluate(X_train,Y_train,verbose=0)
test_result = model.evaluate(X_test,Y_test_encod,verbose=0)
val_result = model.evaluate(X_val,Y_val,verbose=0)

# %%
cols = ['Loss', 'dice_coef', 'Accuracy']
rows = ['Train Result','Validation Result', 'Test Result']

cell_text = [train_result, val_result, test_result]

rcolors = plt.cm.BuPu(np.full(len(rows), 0.1))
ccolors = plt.cm.BuPu(np.full(len(cols), 0.1))

plt.figure(linewidth=4,
           facecolor= 'white'
          )

the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=rcolors,
                      colColours=ccolors,
                      colLabels=cols,
                      loc='center')

the_table.scale(1.5, 2.5)

plt.suptitle('Results of HGG', fontsize=20)

ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.box(on=None)

# %%
model.save('vnet-model.h5',overwrite=True)
